# %%
DF_PATH       = "../data/processed/2_cleaned_data.pkl"

MLFLOW_TRACKING_URI = '../models/mlruns'
MLFLOW_EXPERIMENT_NAME = "skills_jobs_stackoverflow"

LOG_PATH = "../models/temp/"
LOG_DATA_PKL    =  "data.pkl"
LOG_MODEL_PKL   =  "model.pkl"
LOG_METRICS_PKL =  "metrics.pkl"

# %%
# Load packages
import pandas as pd 
import numpy as np
import logging
import pickle
import random
# import plotly 
import os
from pathlib import Path

import mlflow
from mlflow.tracking import MlflowClient

from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn import metrics
from sklearn.metrics import auc, accuracy_score, confusion_matrix, f1_score, precision_score, recall_score

from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
# Out:
# C:\Users\MR\anaconda3\lib\site-packages\paramiko\transport.py:236: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (pyOpenSSL 23.0.0 (c:\users\mr\anaconda3\lib\site-packages), Requirement.parse('pyopenssl<23.0.0')).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception (pyOpenSSL 23.0.0 (c:\users\mr\anaconda3\lib\site-packages), Requirement.parse('pyopenssl<23.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception (pyOpenSSL 23.0.0 (c:\users\mr\anaconda3\lib\site-packages), Requirement.parse('pyopenssl<23.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception (pyOpenSSL 23.0.0 (c:\users\mr\anaconda3\lib\site-packages), Requirement.parse('pyopenssl<23.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (pyOpenSSL 23.0.0 (c:\users\mr\anaconda3\lib\site-packages), Requirement.parse('pyopenssl<23.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint hyperdrive = azureml.train.hyperdrive:HyperDriveRun._from_run_dto with exception (pyOpenSSL 23.0.0 (c:\users\mr\anaconda3\lib\site-packages), Requirement.parse('pyopenssl<23.0.0'), {'azureml-core'}).

# %% [markdown]
# _________

# %% [markdown]
# ### Functions

# %%
def calculate_performance(ground_truth, predictions, metric_function, sort_values=False):
    performance_scores = {}
    #loop over roles
    for col in predictions.columns:
        role_pred  = predictions[col].copy()
        role_truth = ground_truth[col].copy()
        #calculate metric performance for the role
        performance_scores[col] = round(metric_function(role_truth, role_pred) * 100, 2)
        
    performance_scores = pd.Series(performance_scores.values(), index=performance_scores.keys())
    if sort_values:
        performance_scores = performance_scores.sort_values()
    
    return performance_scores

# %% [markdown]
# -------------

# %% [markdown]
# ## Prep data

# %%
# Read Data
df = pd.read_pickle(DF_PATH)

# %% [markdown]
# ### Balance classes

# %%
# Check the total samples of roles
roles_df = df["DevType"].copy()
roles_df.sum(axis=0)
# Out:
# Academic researcher                               1506
# Blockchain                                         557
# Cloud infrastructure engineer                     1956
# Data or business analyst                          1254
# Data scientist or machine learning specialist     1854
# Database administrator                             950
# DevOps specialist                                 2329
# Developer, QA or test                              986
# Developer, back-end                              15444
# Developer, desktop or enterprise applications     4230
# Developer, embedded applications or devices       1771
# Developer, front-end                              7781
# Developer, full-stack                            17221
# Developer, game or graphics                        786
# Developer, mobile                                 3635
# Engineer, data                                    1597
# Project manager                                   1211
# Scientist                                          889
# Security professional                              567
# System administrator                              1321
# dtype: int64

# %%
# Resample roles
samples_per_class = 1200
resampled_roles = []

for role_col in roles_df.columns:
    sub_df = roles_df.loc[roles_df[role_col] == 1].copy()

    if len(sub_df) < samples_per_class:
        # Upsample
        sub_df = sub_df.sample(samples_per_class, replace=True, random_state=0)
    else:
        # Downsample
        sub_df = sub_df.sample(samples_per_class, random_state=0)

    resampled_roles.append(sub_df)

# %%
resampled_roles_df = pd.concat(resampled_roles)
print(f"Shape of resampled roles dataframe : {resampled_roles_df.shape}")
# Out:
# Shape of resampled roles dataframe : (24000, 20)

# %%
resampled_roles_df.sum(axis=0)
# Out:
# Academic researcher                              2414
# Blockchain                                       1428
# Cloud infrastructure engineer                    2316
# Data or business analyst                         2022
# Data scientist or machine learning specialist    2499
# Database administrator                           1803
# DevOps specialist                                2521
# Developer, QA or test                            1519
# Developer, back-end                              7048
# Developer, desktop or enterprise applications    3078
# Developer, embedded applications or devices      1934
# Developer, front-end                             2769
# Developer, full-stack                            6631
# Developer, game or graphics                      1504
# Developer, mobile                                2162
# Engineer, data                                   2144
# Project manager                                  1809
# Scientist                                        1936
# Security professional                            1531
# System administrator                             2172
# dtype: int64

# %%
# Construct dfs
# roles_df = pd.concat(resampled_roles)
df = df.loc[roles_df.index].copy()

# %% [markdown]
# ## Split to train and test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.drop('DevType', axis=1),
                                                    df['DevType'],
                                                    random_state=0)
# Out:
# C:\Users\MR\AppData\Local\Temp\ipykernel_7076\2536690730.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X_train, X_test, Y_train, Y_test = train_test_split(df.drop('DevType', axis=1),

# %% [markdown]
# _________

# %% [markdown]
# # Train models

# %% [markdown]
# ### Initialize MLflow

# %%
# Initialize client and experiment
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
mlflow.set_experiment(MLFLOW_EXPERIMENT_NAME)
client = MlflowClient()
mlflow.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)

# %% [markdown]
# ### 1. RandomForest

# %%
rf_clf = make_pipeline(RobustScaler(),
                       PCA(n_components=0.95),
                       RandomForestClassifier(n_jobs=8,
                                              verbose=1,
                                              random_state=0))

rf_clf.fit(X_train, Y_train)
# Out:
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:   19.7s finished
# Pipeline(steps=[('robustscaler', RobustScaler()),
#                 ('pca', PCA(n_components=0.95)),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(n_jobs=8, random_state=0, verbose=1))])

# %%
# Evaluate on train set
predictions =  pd.DataFrame(rf_clf.predict(X_train),
                            columns=Y_train.columns)
train_scores = {score.__name__: calculate_performance(Y_train, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores = pd.concat(train_scores,axis=1)
# Out:
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.0s finished

# %%
# Evaluate on test set
predictions =  pd.DataFrame(rf_clf.predict(X_test),
                            columns=Y_test.columns)
test_scores = {score.__name__: calculate_performance(Y_test, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores = pd.concat(test_scores,axis=1)
mean_test_scores = test_scores.mean()
# Out:
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.6s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(test_scores.mean())
test_scores.sort_values("precision_score")
# Out:
# accuracy_score     93.4135
# precision_score    48.9110
# recall_score       10.8330
# f1_score           14.9070
# dtype: float64
#                                                accuracy_score  \
# System administrator                                    96.61
# Blockchain                                              98.64
# Project manager                                         97.19
# Database administrator                                  97.73
# Developer, QA or test                                   97.58
# Security professional                                   98.69
# Data or business analyst                                96.82
# Developer, game or graphics                             98.09
# Cloud infrastructure engineer                           95.22
# DevOps specialist                                       94.49
# Developer, back-end                                     70.81
# Developer, full-stack                                   74.52
# Developer, desktop or enterprise applications           90.76
# Developer, front-end                                    84.21
# Developer, embedded applications or devices             96.18
# Scientist                                               97.85
# Academic researcher                                     96.37
# Data scientist or machine learning specialist           96.16
# Developer, mobile                                       94.27
# Engineer, data                                          96.08
#
#                                                precision_score  recall_score  \
# System administrator                                      0.00          0.00
# Blockchain                                                0.00          0.00
# Project manager                                           0.00          0.00
# Database administrator                                    0.00          0.00
# Developer, QA or test                                     0.00          0.00
# Security professional                                     0.00          0.00
# Data or business analyst                                 37.50          0.91
# Developer, game or graphics                              44.44          2.02
# Cloud infrastructure engineer                            50.00          0.20
# DevOps specialist                                        62.50          2.59
# Developer, back-end                                      70.05         36.73
# Developer, full-stack                                    70.94         65.64
# Developer, desktop or enterprise applications            71.79         10.87
# Developer, front-end                                     71.93         24.53
# Developer, embedded applications or devices              72.22         12.09
# Scientist                                                75.00          1.33
# Academic researcher                                      78.26          4.60
# Data scientist or machine learning specialist            79.82         19.44
# Developer, mobile                                        93.77         35.47
# Engineer, data                                          100.00          0.24
#
#                                                f1_score
# System administrator                               0.00
# Blockchain                                         0.00
# Project manager                                    0.00
# Database administrator                             0.00
# Developer, QA or test                              0.00
# Security professional                              0.00
# Data or business analyst                           1.78
# Developer, game or graphics                        3.86
# Cloud infrastructure engineer                      0.40
# DevOps specialist                                  4.98
# Developer, back-end                               48.19
# Developer, full-stack                             68.19
# Developer, desktop or enterprise applications     18.89
# Developer, front-end                              36.59
# Developer, embedded applications or devices       20.72
# Scientist                                          2.61
# Academic researcher                                8.70
# Data scientist or machine learning specialist     31.27
# Developer, mobile                                 51.47
# Engineer, data                                     0.49

# %% [markdown]
# ### Log

# %%
## Log
# Data details
data_details = {"data_path": DF_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices": X_test.index.tolist(),
                "features_names": X_train.columns.droplevel(0).tolist(),
                "targets_names": Y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), "wb") as output_file:
    pickle.dump(data_details, output_file)

# %%
# Model
model = {"model_description": "Random Forest: with PCA - Basic",
         "model_details": str(rf_clf),
         "model_object": rf_clf}

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
# Performance details
classes_metrics = {"train_scores": train_scores,
                   "test_scores": test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %%
# Start a new run and track
with mlflow.start_run(experiment_id=exp.experiment_id,
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)

    # Track metrics
    for metric, score in mean_test_scores.items():
        mlflow.log_metric(metric, score)

# %% [markdown]
# ______________

# %% [markdown]
# ### 2. Hyper parameter tuning

# %%
hpt_rf_clf = make_pipeline(RobustScaler(),
                           PCA(),
                           RandomForestClassifier(n_jobs=8,
                                                  verbose=1,
                                                  random_state=0))

# %%
# list(hpt_rf_clf.get_params().keys())
tuned_parameters = [{
    'pca__n_components': [0.7, 0.85, 0.95],
    'randomforestclassifier__n_estimators': [250, 500],
    'randomforestclassifier__max_depth':    [3, 10, None],
}]

# %%
hpt_rf_clf = GridSearchCV(hpt_rf_clf, tuned_parameters)
hpt_rf_clf.fit(X_train, Y_train)
# Out:
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.7s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.1s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    4.6s remaining:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.8s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.3s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.8s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.1s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.7s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.2s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.1s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.2s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    9.8s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.7s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    9.6s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.5s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    9.8s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.3s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   10.1s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.3s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   10.0s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.3s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   10.1s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.3s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.7s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.3s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.9s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.2s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   10.1s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.2s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.9s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.4s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   19.9s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.8s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   19.9s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.9s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   19.7s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.8s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   19.7s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.2s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   19.8s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.8s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   18.0s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.3s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   19.9s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.4s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   18.0s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.2s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   17.8s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.4s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   18.2s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.3s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   37.2s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.6s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   39.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   44.0s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.6s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   37.8s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.1s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   33.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   38.5s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.7s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   43.4s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.0s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    8.3s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.2s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.1s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.1s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.2s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.3s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.2s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.3s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.0s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.9s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.9s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.8s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   15.9s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.5s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# ...
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.9s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   36.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   41.9s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.0s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   43.1s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.4s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   40.1s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.4s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   38.3s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.3s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   37.7s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.5s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   39.6s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.4s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.3min finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.7s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.3min finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.8s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.2min finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.8s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.3min finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.8s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   29.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.3min finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.9s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   47.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   53.9s finished
# GridSearchCV(estimator=Pipeline(steps=[('robustscaler', RobustScaler()),
#                                        ('pca', PCA()),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier(n_jobs=8,
#                                                                random_state=0,
#                                                                verbose=1))]),
#              param_grid=[{'pca__n_components': [0.7, 0.85, 0.95],
#                           'randomforestclassifier__max_depth': [3, 10, None],
#                           'randomforestclassifier__n_estimators': [250, 500]}])

# %%
hpt_rf_clf.best_params_
# Out:
# {'pca__n_components': 0.7,
#  'randomforestclassifier__max_depth': None,
#  'randomforestclassifier__n_estimators': 500}

# %%
# Evaluate on test set
predictions =  pd.DataFrame(hpt_rf_clf.predict(X_train),
                            columns=Y_train.columns)
train_scores = {score.__name__: calculate_performance(Y_train, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores = pd.concat(train_scores,axis=1)
# Out:
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   11.0s finished

# %%
# Evaluate on test set
predictions =  pd.DataFrame(hpt_rf_clf.predict(X_test),
                            columns=Y_test.columns)
test_scores = {score.__name__: calculate_performance(Y_test, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores = pd.concat(test_scores,axis=1)
# Out:
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.2s finished
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\MR\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(test_scores.mean())
test_scores
# Out:
# accuracy_score     93.4655
# precision_score    42.7620
# recall_score       12.5020
# f1_score           16.6035
# dtype: float64
#                                                accuracy_score  \
# Academic researcher                                     96.44
# Blockchain                                              98.64
# Cloud infrastructure engineer                           95.25
# Data or business analyst                                96.80
# Data scientist or machine learning specialist           96.24
# Database administrator                                  97.72
# DevOps specialist                                       94.60
# Developer, QA or test                                   97.58
# Developer, back-end                                     70.97
# Developer, desktop or enterprise applications           90.42
# Developer, embedded applications or devices             96.09
# Developer, front-end                                    84.34
# Developer, full-stack                                   75.03
# Developer, game or graphics                             98.04
# Developer, mobile                                       94.76
# Engineer, data                                          96.09
# Project manager                                         97.19
# Scientist                                               97.81
# Security professional                                   98.69
# System administrator                                    96.61
#
#                                                precision_score  recall_score  \
# Academic researcher                                      80.00          7.16
# Blockchain                                                0.00          0.00
# Cloud infrastructure engineer                            57.89          2.21
# Data or business analyst                                 25.00          0.61
# Data scientist or machine learning specialist            73.05         26.07
# Database administrator                                    0.00          0.00
# DevOps specialist                                        69.77          5.18
# Developer, QA or test                                     0.00          0.00
# Developer, back-end                                      67.69         41.07
# Developer, desktop or enterprise applications            60.65          9.13
# Developer, embedded applications or devices              62.92         13.02
# Developer, front-end                                     68.83         28.57
# Developer, full-stack                                    70.10         69.72
# Developer, game or graphics                              20.00          1.01
# Developer, mobile                                        91.00         43.10
# Engineer, data                                           66.67          0.98
# Project manager                                           0.00          0.00
# Scientist                                                41.67          2.21
# Security professional                                     0.00          0.00
# System administrator                                      0.00          0.00
#
#                                                f1_score
# Academic researcher                               13.15
# Blockchain                                         0.00
# Cloud infrastructure engineer                      4.26
# Data or business analyst                           1.19
# Data scientist or machine learning specialist     38.43
# Database administrator                             0.00
# DevOps specialist                                  9.65
# Developer, QA or test                              0.00
# Developer, back-end                               51.12
# Developer, desktop or enterprise applications     15.86
# Developer, embedded applications or devices       21.58
# Developer, front-end                              40.38
# Developer, full-stack                             69.91
# Developer, game or graphics                        1.92
# Developer, mobile                                 58.49
# Engineer, data                                     1.93
# Project manager                                    0.00
# Scientist                                          4.20
# Security professional                              0.00
# System administrator                               0.00

# %% [markdown]
# ## Log

# %%
# Data details
data_details = {"data_path": DF_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices":     X_test.index.tolist(), 
                "features_names":   X_train.columns.droplevel(0).tolist(),
                "targets_names":    Y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), "wb") as output_file:
    pickle.dump(data_details, output_file)

# %%
# Model
model = {"model_description": "Random Forest: with PCA + Hyperparamter tuning",
         "model_details": str(hpt_rf_clf),
         "model_object": hpt_rf_clf} 

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
# Preformance details
classes_metrics = {"train_scores": train_scores, 
                   "test_scores":  test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %%
# Start a new run and track 
with mlflow.start_run(experiment_id=exp.experiment_id, 
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)  
    
    # Track metrics 
    for metric, score in mean_test_scores.items():
        mlflow.log_metric(metric, score)
