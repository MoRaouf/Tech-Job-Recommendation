# %%
DF_PATH = "../data/processed/2_cleaned_data.pkl"

MLFLOW_TRACKING_URI = '../models/mlruns'
MLFLOW_EXPERIMENT_NAME = "skills_jobs_stackoveflow"

LOG_PATH = "../models/temp/"
LOG_DATA_PKL    =  "data.pkl"
LOG_MODEL_PKL   =  "model.pkl"
LOG_METRICS_PKL =  "metrics.pkl"

# %%
# Load packages
import pandas as pd 
import numpy as np
import logging
import pickle
import random
# import plotly 
import os
from pathlib import Path

import mlflow
from mlflow.tracking import MlflowClient

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import train_test_split

from sklearn import metrics
from sklearn.metrics import auc, accuracy_score, confusion_matrix, f1_score, precision_score, recall_score

from sklearn.linear_model import LogisticRegression

# %% [markdown]
# _________

# %% [markdown]
# ### Functions

# %%
def calculate_performance(ground_truth, predictions, metric_function, sort_values=False):
    performance_scores = {}
    #loop over roles
    for col in predictions.columns:
        role_pred  = predictions[col].copy()
        role_truth = ground_truth[col].copy()
        #calculate metric performance for the role
        performance_scores[col] = round(metric_function(role_truth, role_pred) * 100, 2)
        
    performance_scores = pd.Series(performance_scores.values(), index=performance_scores.keys())
    if sort_values:
        performance_scores = performance_scores.sort_values()
    
    return performance_scores

# %% [markdown]
# _________

# %% [markdown]
# # Initialize

# %% [markdown]
# ### Create directories

# %%
Path(MLFLOW_TRACKING_URI).mkdir(parents=True, exist_ok=True)
Path(LOG_PATH).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Read data

# %%
# Read Data
df = pd.read_pickle(DF_PATH)
df
# Out:
#                   DevType                                           \
#       Academic researcher Blockchain Cloud infrastructure engineer
# 2                       0          0                             0
# 3                       0          0                             0
# 7                       0          0                             0
# 9                       0          0                             0
# 10                      0          0                             0
# ...                   ...        ...                           ...
# 73262                   0          0                             0
# 73263                   0          0                             0
# 73264                   0          0                             0
# 73265                   0          0                             0
# 73266                   0          0                             0
#
#                                                                               \
#       Data or business analyst Data scientist or machine learning specialist
# 2                            0                                             1
# 3                            0                                             0
# 7                            0                                             0
# 9                            0                                             0
# 10                           0                                             0
# ...                        ...                                           ...
# 73262                        0                                             0
# 73263                        0                                             0
# 73264                        0                                             1
# 73265                        0                                             0
# 73266                        0                                             0
#
#                                                                       \
#       Database administrator DevOps specialist Developer, QA or test
# 2                          0                 0                     0
# 3                          0                 0                     0
# 7                          0                 0                     0
# 9                          0                 0                     0
# 10                         0                 0                     0
# ...                      ...               ...                   ...
# 73262                      0                 0                     0
# 73263                      0                 0                     0
# 73264                      0                 0                     0
# 73265                      0                 0                     0
# 73266                      0                 0                     0
#
#                                                                          ...  \
#       Developer, back-end Developer, desktop or enterprise applications  ...
# 2                       0                                             0  ...
# 3                       0                                             0  ...
# 7                       0                                             0  ...
# 9                       0                                             1  ...
# 10                      1                                             0  ...
# ...                   ...                                           ...  ...
# 73262                   0                                             0  ...
# 73263                   1                                             0  ...
# 73264                   0                                             0  ...
# 73265                   0                                             1  ...
# 73266                   0                                             1  ...
#
#       skills_clusters                                                 \
#        skills_group_2 skills_group_20 skills_group_21 skills_group_3
# 2                   0               0               0              0
# 3                   0               0               0              0
# 7                   1               0               0              0
# 9                   2               0               0              0
# 10                  0               1               0              0
# ...               ...             ...             ...            ...
# 73262               1               0               0              0
# 73263               0               1               0              0
# 73264               1               1               0              0
# 73265               0               0               0              0
# 73266               1               0               0              0
#
#                                                                    \
#       skills_group_4 skills_group_5 skills_group_6 skills_group_7
# 2                  0              0              2              0
# 3                  0              0              6              0
# 7                  0              0              1              2
# 9                  0              0              1              0
# 10                 1              0              7              0
# ...              ...            ...            ...            ...
# 73262              0              0              0              0
# 73263              4              0              1              2
# 73264              0              0              1              1
# 73265              1              0              4              4
# 73266              0              0              4              0
#
#
#       skills_group_8 skills_group_9
# 2                  0              0
# 3                  0              0
# 7                  0              0
# 9                  0              0
# 10                 0              0
# ...              ...            ...
# 73262              0              0
# 73263              2              0
# 73264              1              0
# 73265              0              0
# 73266              0              0
#
# [41626 rows x 203 columns]

# %% [markdown]
# ### Balance classes

# %%
# Check the total samples of roles
roles_df = df["DevType"].copy()
roles_df.sum(axis=0)
# Out:
# Academic researcher                               1506
# Blockchain                                         557
# Cloud infrastructure engineer                     1956
# Data or business analyst                          1254
# Data scientist or machine learning specialist     1854
# Database administrator                             950
# DevOps specialist                                 2329
# Developer, QA or test                              986
# Developer, back-end                              15444
# Developer, desktop or enterprise applications     4230
# Developer, embedded applications or devices       1771
# Developer, front-end                              7781
# Developer, full-stack                            17221
# Developer, game or graphics                        786
# Developer, mobile                                 3635
# Engineer, data                                    1597
# Project manager                                   1211
# Scientist                                          889
# Security professional                              567
# System administrator                              1321
# dtype: int64

# %%
print(f"Shape of roles dataframe : {roles_df.shape}")
roles_df.head(3)
# Out:
# Shape of roles dataframe : (41626, 20)
#    Academic researcher  Blockchain  Cloud infrastructure engineer  \
# 2                    0           0                              0
# 3                    0           0                              0
# 7                    0           0                              0
#
#    Data or business analyst  Data scientist or machine learning specialist  \
# 2                         0                                              1
# 3                         0                                              0
# 7                         0                                              0
#
#    Database administrator  DevOps specialist  Developer, QA or test  \
# 2                       0                  0                      0
# 3                       0                  0                      0
# 7                       0                  0                      0
#
#    Developer, back-end  Developer, desktop or enterprise applications  \
# 2                    0                                              0
# 3                    0                                              0
# 7                    0                                              0
#
#    Developer, embedded applications or devices  Developer, front-end  \
# 2                                            0                     1
# 3                                            0                     0
# 7                                            0                     0
#
#    Developer, full-stack  Developer, game or graphics  Developer, mobile  \
# 2                      0                            0                  0
# 3                      1                            0                  0
# 7                      1                            0                  0
#
#    Engineer, data  Project manager  Scientist  Security professional  \
# 2               1                0          0                      0
# 3               0                0          0                      0
# 7               0                0          0                      0
#
#    System administrator
# 2                     0
# 3                     0
# 7                     0

# %%
#Resample roles
samples_per_class = 1200
resampled_roles = []

for role in roles_df.columns:
    #get the role samples
    sub_df = roles_df.loc[roles_df[role]==1].copy()
    
    if len(sub_df) < samples_per_class:
        #Upsample
        sub_df = sub_df.sample(samples_per_class, replace=True, random_state=11)
    else:
        #Downsample
        sub_df = sub_df.sample(samples_per_class, random_state=11)
        
    resampled_roles.append(sub_df)

# %%
resampled_roles_df = pd.concat(resampled_roles)
print(f"Shape of resampled roles dataframe : {resampled_roles_df.shape}")
resampled_roles_df.head(3)
# Out:
# Shape of resampled roles dataframe : (24000, 20)
#        Academic researcher  Blockchain  Cloud infrastructure engineer  \
# 14714                    1           0                              0
# 38157                    1           0                              0
# 28458                    1           0                              0
#
#        Data or business analyst  \
# 14714                         0
# 38157                         0
# 28458                         0
#
#        Data scientist or machine learning specialist  Database administrator  \
# 14714                                              0                       0
# 38157                                              0                       0
# 28458                                              0                       0
#
#        DevOps specialist  Developer, QA or test  Developer, back-end  \
# 14714                  0                      0                    0
# 38157                  0                      0                    0
# 28458                  0                      0                    0
#
#        Developer, desktop or enterprise applications  \
# 14714                                              0
# 38157                                              0
# 28458                                              0
#
#        Developer, embedded applications or devices  Developer, front-end  \
# 14714                                            0                     0
# 38157                                            0                     0
# 28458                                            0                     0
#
#        Developer, full-stack  Developer, game or graphics  Developer, mobile  \
# 14714                      0                            0                  0
# 38157                      0                            0                  0
# 28458                      0                            0                  0
#
#        Engineer, data  Project manager  Scientist  Security professional  \
# 14714               0                0          0                      1
# 38157               0                0          1                      0
# 28458               0                0          0                      0
#
#        System administrator
# 14714                     0
# 38157                     0
# 28458                     0

# %%
resampled_roles_df.sum(axis=0)
# Out:
# Academic researcher                              2494
# Blockchain                                       1433
# Cloud infrastructure engineer                    2317
# Data or business analyst                         2014
# Data scientist or machine learning specialist    2477
# Database administrator                           1815
# DevOps specialist                                2484
# Developer, QA or test                            1545
# Developer, back-end                              6928
# Developer, desktop or enterprise applications    2980
# Developer, embedded applications or devices      1889
# Developer, front-end                             2759
# Developer, full-stack                            6659
# Developer, game or graphics                      1481
# Developer, mobile                                2094
# Engineer, data                                   2072
# Project manager                                  1769
# Scientist                                        1943
# Security professional                            1525
# System administrator                             2134
# dtype: int64

# %%
# Construct dfs
# roles_df  = pd.concat(resampled_roles)
df = df.loc[roles_df.index].copy()
df.head(3)
# Out:
#               DevType                                           \
#   Academic researcher Blockchain Cloud infrastructure engineer
# 2                   0          0                             0
# 3                   0          0                             0
# 7                   0          0                             0
#
#                                                                           \
#   Data or business analyst Data scientist or machine learning specialist
# 2                        0                                             1
# 3                        0                                             0
# 7                        0                                             0
#
#                                                                   \
#   Database administrator DevOps specialist Developer, QA or test
# 2                      0                 0                     0
# 3                      0                 0                     0
# 7                      0                 0                     0
#
#                                                                      ...  \
#   Developer, back-end Developer, desktop or enterprise applications  ...
# 2                   0                                             0  ...
# 3                   0                                             0  ...
# 7                   0                                             0  ...
#
#   skills_clusters                                                 \
#    skills_group_2 skills_group_20 skills_group_21 skills_group_3
# 2               0               0               0              0
# 3               0               0               0              0
# 7               1               0               0              0
#
#                                                                               \
#   skills_group_4 skills_group_5 skills_group_6 skills_group_7 skills_group_8
# 2              0              0              2              0              0
# 3              0              0              6              0              0
# 7              0              0              1              2              0
#
#
#   skills_group_9
# 2              0
# 3              0
# 7              0
#
# [3 rows x 203 columns]

# %% [markdown]
# ### Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.drop("DevType", axis=1), 
                                                    df["DevType"], 
                                                    random_state=11)
# Out:
# C:\Users\MR\AppData\Local\Temp\ipykernel_30768\3849173009.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X_train, X_test, Y_train, Y_test = train_test_split(df.drop("DevType", axis=1),

# %% [markdown]
# ____________

# %% [markdown]
# # Train models

# %% [markdown]
# ### Initialize MLflow

# %%
# Initialize client and experiment
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
mlflow.set_experiment(MLFLOW_EXPERIMENT_NAME)
client = MlflowClient()
mlflow.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)

# %% [markdown]
# ### 1. Logistic regression

# %%
clf = make_pipeline(StandardScaler(),
                    MultiOutputClassifier(LogisticRegression()))

clf.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('multioutputclassifier',
#                  MultiOutputClassifier(estimator=LogisticRegression()))])

# %%
# Evaluate on training set
predictions =  pd.DataFrame(clf.predict(X_train),
                            columns=Y_train.columns)
train_scores = {score.__name__: calculate_performance(Y_train, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores = pd.concat(train_scores,axis=1)
# Out:
# C:\Users\MR\anaconda3\envs\Pytorch-GPU CUDA113\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\MR\anaconda3\envs\Pytorch-GPU CUDA113\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Evaluate on test set
predictions =  pd.DataFrame(clf.predict(X_test), columns=Y_test.columns)
test_scores = {score.__name__: calculate_performance(Y_test, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores = pd.concat(test_scores,axis=1)
mean_test_scores = test_scores.mean()
# Out:
# C:\Users\MR\anaconda3\envs\Pytorch-GPU CUDA113\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\MR\anaconda3\envs\Pytorch-GPU CUDA113\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\MR\anaconda3\envs\Pytorch-GPU CUDA113\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(mean_test_scores)
test_scores
# Out:
# accuracy_score     93.5885
# precision_score    47.7410
# recall_score       21.1040
# f1_score           27.3780
# dtype: float64
#                                                accuracy_score  \
# Academic researcher                                     96.74
# Blockchain                                              98.76
# Cloud infrastructure engineer                           95.42
# Data or business analyst                                96.87
# Data scientist or machine learning specialist           96.44
# Database administrator                                  97.75
# DevOps specialist                                       94.77
# Developer, QA or test                                   97.45
# Developer, back-end                                     71.98
# Developer, desktop or enterprise applications           90.26
# Developer, embedded applications or devices             96.01
# Developer, front-end                                    84.93
# Developer, full-stack                                   73.20
# Developer, game or graphics                             98.19
# Developer, mobile                                       95.44
# Engineer, data                                          96.62
# Project manager                                         97.20
# Scientist                                               98.09
# Security professional                                   98.88
# System administrator                                    96.77
#
#                                                precision_score  recall_score  \
# Academic researcher                                      59.43         17.55
# Blockchain                                               46.15          9.45
# Cloud infrastructure engineer                            51.38         11.67
# Data or business analyst                                 48.05         11.46
# Data scientist or machine learning specialist            65.90         43.04
# Database administrator                                    0.00          0.00
# DevOps specialist                                        64.19         16.21
# Developer, QA or test                                     0.00          0.00
# Developer, back-end                                      67.32         48.66
# Developer, desktop or enterprise applications            65.11         16.48
# Developer, embedded applications or devices              67.11         21.84
# Developer, front-end                                     68.17         40.66
# Developer, full-stack                                    68.08         66.26
# Developer, game or graphics                              54.88         22.96
# Developer, mobile                                        80.00         62.81
# Engineer, data                                           65.59         16.01
# Project manager                                           0.00          0.00
# Scientist                                                45.00         13.99
# Security professional                                     0.00          0.00
# System administrator                                     38.46          3.03
#
#                                                f1_score
# Academic researcher                               27.10
# Blockchain                                        15.69
# Cloud infrastructure engineer                     19.02
# Data or business analyst                          18.50
# Data scientist or machine learning specialist     52.07
# Database administrator                             0.00
# DevOps specialist                                 25.89
# Developer, QA or test                              0.00
# Developer, back-end                               56.49
# Developer, desktop or enterprise applications     26.31
# Developer, embedded applications or devices       32.96
# Developer, front-end                              50.94
# Developer, full-stack                             67.15
# Developer, game or graphics                       32.37
# Developer, mobile                                 70.37
# Engineer, data                                    25.74
# Project manager                                    0.00
# Scientist                                         21.34
# Security professional                              0.00
# System administrator                               5.62

# %% [markdown]
# ## Log run

# %% [markdown]
# ### 1. Prepare

# %%
# Data details
data_details = {"data_path": DF_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices":     X_test.index.tolist(), 
                "features_names":   X_train.columns.droplevel(0).tolist(),
                "targets_names":    Y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), "wb") as output_file:
    pickle.dump(data_details, output_file)

# %%
# Model
model = {"model_description": "Baseline model: Logistic Regression ",
         "model_details": str(clf),
         "model_object": clf} 

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
# Performance details
classes_metrics = {"train_scores": train_scores, 
                   "test_scores":  test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %% [markdown]
# ### 2. Log

# %%
# Start a new run and track 
with mlflow.start_run(experiment_id=exp.experiment_id, run_name=model["model_description"]):
    # Log pickles 
    mlflow.log_artifacts(LOG_PATH)
    
    # Track metrics 
    for metric, score in mean_test_scores.items():
        mlflow.log_metric(metric, score)
